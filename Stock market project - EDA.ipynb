# %% [markdown]
# ## Collection of Dataset
#
# - For this project, we will be using the Yfinance library to get the data, which makes it easy to process.
#
# - We collected data from 1-Jan-2015 to 31-Dec-2023.
#
# - But also you can download data from ‘Yahoo! Finance’ website. You can use Below link.
#
# - https://finance.yahoo.com/quote/RELIANCE.NS/history?p=RELIANCE.NS

# %% [markdown]
# ## About the data
#
# - Date: Date of trade
#
# - Open: Opening Price of Stock
#
# - High: Highest price of stock on that day
#
# - Low: Lowest price of stock on that day
#
# - Close: Close price adjusted for splits.
#
# - Adj  Close: Adjusted close price adjusted for splits and dividend and/or capital gain distributions.
#
# - Volume: Volume of stock on that day

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

import warnings
warnings.filterwarnings("ignore")

# %%
#!pip install yfinance

# %%
# Importing dataset
data=yf.download('RELIANCE.NS', start='2015-1-1', end='2022-12-31').reset_index(drop=False)
reliance_0 = pd.DataFrame(data)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
reliance_0.head(10)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2015-01-01  438.988831  441.812073  437.676270  439.781311  416.517578
# 1 2015-01-02  439.880371  443.818054  437.998199  438.617340  415.415192
# 2 2015-01-05  438.344940  441.267212  432.946106  433.812897  410.864868
# 3 2015-01-06  430.915344  432.401276  412.093750  414.124512  392.217957
# 4 2015-01-07  414.619812  425.367950  414.570282  423.139069  400.755646
# 5 2015-01-08  426.011841  427.398682  416.130493  417.071564  395.009155
# 6 2015-01-09  420.216766  426.952911  418.532715  426.110901  403.570251
# 7 2015-01-12  426.209961  426.457611  416.848694  421.157837  398.879242
# 8 2015-01-13  422.495178  423.460999  416.303864  417.616425  395.525177
# 9 2015-01-14  417.542114  419.523346  411.697510  413.554901  391.678497
#
#     Volume
# 0  1367720
# 1  3383424
# 2  4662967
# 3  8596809
# 4  9562421
# 5  9171029
# 6  6180769
# 7  4661200
# 8  4591328
# 9  5251887

# %%
reliance_0.tail(10)
# Out:
#            Date         Open         High          Low        Close  \
# 1966 2022-12-19  2581.000000  2604.000000  2566.699951  2599.300049
# 1967 2022-12-20  2583.899902  2626.000000  2566.000000  2621.800049
# 1968 2022-12-21  2621.000000  2633.000000  2576.100098  2584.500000
# 1969 2022-12-22  2598.000000  2604.649902  2566.750000  2577.800049
# 1970 2022-12-23  2563.300049  2590.500000  2492.250000  2502.199951
# 1971 2022-12-26  2514.750000  2542.000000  2492.399902  2524.050049
# 1972 2022-12-27  2530.000000  2548.800049  2515.250000  2544.699951
# 1973 2022-12-28  2538.000000  2549.800049  2521.500000  2544.449951
# 1974 2022-12-29  2527.000000  2548.899902  2525.500000  2543.300049
# 1975 2022-12-30  2545.100098  2577.000000  2541.100098  2547.199951
#
#         Adj Close   Volume
# 1966  2590.150391  3567363
# 1967  2612.571289  3446291
# 1968  2575.402588  3935463
# 1969  2568.726074  3438692
# 1970  2493.392090  4733657
# 1971  2515.165283  2764496
# 1972  2535.742676  2659749
# 1973  2535.493408  3442509
# 1974  2534.347656  3198493
# 1975  2538.233887  3364092

# %%
reliance_0.shape
# Out:
# (1976, 7)

# %% [markdown]
# # EDA

# %% [markdown]
# Analysis is only based on Open, High, Low, close price and volume
#
# There is no need of Adj Close

# %%
# Removing "Adj Close" columnfrom dataset
reliance_1=reliance_0.drop(["Adj Close"],axis=1).reset_index(drop=True)
reliance_1
# Out:
#            Date         Open         High          Low        Close   Volume
# 0    2015-01-01   438.988831   441.812073   437.676270   439.781311  1367720
# 1    2015-01-02   439.880371   443.818054   437.998199   438.617340  3383424
# 2    2015-01-05   438.344940   441.267212   432.946106   433.812897  4662967
# 3    2015-01-06   430.915344   432.401276   412.093750   414.124512  8596809
# 4    2015-01-07   414.619812   425.367950   414.570282   423.139069  9562421
# ...         ...          ...          ...          ...          ...      ...
# 1971 2022-12-26  2514.750000  2542.000000  2492.399902  2524.050049  2764496
# 1972 2022-12-27  2530.000000  2548.800049  2515.250000  2544.699951  2659749
# 1973 2022-12-28  2538.000000  2549.800049  2521.500000  2544.449951  3442509
# 1974 2022-12-29  2527.000000  2548.899902  2525.500000  2543.300049  3198493
# 1975 2022-12-30  2545.100098  2577.000000  2541.100098  2547.199951  3364092
#
# [1976 rows x 6 columns]

# %%
# Finding duplicate columns, if any
reliance_1[reliance_1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume]
# Index: []

# %%
# Finding null values, if any
reliance_1.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
# Making a copy of dataset as reliance
reliance=reliance_2.copy()
reliance
# Out:
#            Date         Open         High          Low        Close   Volume
# 0    2015-01-01   438.988831   441.812073   437.676270   439.781311  1367720
# 1    2015-01-02   439.880371   443.818054   437.998199   438.617340  3383424
# 2    2015-01-05   438.344940   441.267212   432.946106   433.812897  4662967
# 3    2015-01-06   430.915344   432.401276   412.093750   414.124512  8596809
# 4    2015-01-07   414.619812   425.367950   414.570282   423.139069  9562421
# ...         ...          ...          ...          ...          ...      ...
# 1971 2022-12-26  2514.750000  2542.000000  2492.399902  2524.050049  2764496
# 1972 2022-12-27  2530.000000  2548.800049  2515.250000  2544.699951  2659749
# 1973 2022-12-28  2538.000000  2549.800049  2521.500000  2544.449951  3442509
# 1974 2022-12-29  2527.000000  2548.899902  2525.500000  2543.300049  3198493
# 1975 2022-12-30  2545.100098  2577.000000  2541.100098  2547.199951  3364092
#
# [1976 rows x 6 columns]

# %% [markdown]
# #### Discriptive Statistics

# %%
reliance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1976 entries, 0 to 1975
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1976 non-null   datetime64[ns]
#  1   Open    1976 non-null   float64
#  2   High    1976 non-null   float64
#  3   Low     1976 non-null   float64
#  4   Close   1976 non-null   float64
#  5   Volume  1976 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 92.8 KB

# %%
reliance.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  1976.000000  1976.000000  1976.000000  1976.000000  1.976000e+03
# mean   1315.801554  1330.795265  1300.182943  1314.889481  9.088830e+06
# std     752.202151   760.497187   743.372182   751.597730  6.693435e+06
# min     404.466064   405.010895   394.485657   401.568542  7.871600e+05
# 25%     530.180679   537.337814   525.989166   531.945190  5.242449e+06
# 50%    1171.396301  1187.840454  1151.435547  1171.445862  7.149341e+06
# 75%    2043.350037  2065.924988  2003.612518  2034.700012  1.024994e+07
# max    2856.149902  2856.149902  2786.100098  2819.850098  6.584835e+07

# %%
reliance.corr()
# Out:
#             Open      High       Low     Close    Volume
# Open    1.000000  0.999741  0.999739  0.999460  0.072396
# High    0.999741  1.000000  0.999680  0.999799  0.081515
# Low     0.999739  0.999680  1.000000  0.999773  0.065801
# Close   0.999460  0.999799  0.999773  1.000000  0.074473
# Volume  0.072396  0.081515  0.065801  0.074473  1.000000

# %% [markdown]
# - Every attributes are highly corelated except volume

# %%
# converting the date column in to datetime 
#reliance['Date']=pd.to_datetime(reliance['Date'],format='%Y-%m-%d')
#reliance

# %%
reliance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1976 entries, 0 to 1975
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1976 non-null   datetime64[ns]
#  1   Open    1976 non-null   float64
#  2   High    1976 non-null   float64
#  3   Low     1976 non-null   float64
#  4   Close   1976 non-null   float64
#  5   Volume  1976 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 92.8 KB

# %%
# Setting the date column as index
reliance=reliance.set_index('Date')
reliance
# Out:
#                    Open         High          Low        Close   Volume
# Date
# 2015-01-01   438.988831   441.812073   437.676270   439.781311  1367720
# 2015-01-02   439.880371   443.818054   437.998199   438.617340  3383424
# 2015-01-05   438.344940   441.267212   432.946106   433.812897  4662967
# 2015-01-06   430.915344   432.401276   412.093750   414.124512  8596809
# 2015-01-07   414.619812   425.367950   414.570282   423.139069  9562421
# ...                 ...          ...          ...          ...      ...
# 2022-12-26  2514.750000  2542.000000  2492.399902  2524.050049  2764496
# 2022-12-27  2530.000000  2548.800049  2515.250000  2544.699951  2659749
# 2022-12-28  2538.000000  2549.800049  2521.500000  2544.449951  3442509
# 2022-12-29  2527.000000  2548.899902  2525.500000  2543.300049  3198493
# 2022-12-30  2545.100098  2577.000000  2541.100098  2547.199951  3364092
#
# [1976 rows x 5 columns]

# %% [markdown]
# ### Visualizations

# %%
plt.figure(figsize=(20,10))
#Plot 1
plt.subplot(2,2,1)
plt.plot(reliance['Open'],color='green')
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.title('Open')
#Plot 2
plt.subplot(2,2,2)
plt.plot(reliance['Close'],color='red')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Close')
#Plot 3
plt.subplot(2,2,3)
plt.plot(reliance['High'],color='green')
plt.xlabel('Date')
plt.ylabel('High Price')
plt.title('High')
#Plot 4
plt.subplot(2,2,4)
plt.plot(reliance['Low'],color='red')
plt.xlabel('Date')
plt.ylabel('Low Price')
plt.title('Low')
# Out:
# Text(0.5, 1.0, 'Low')

# %%
# Creating box-plots
plt.figure(figsize=(20,10))
#Plot 1
plt.subplot(2,2,1)
plt.boxplot(reliance['Open'])
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.title('Open')
#Plot 2
plt.subplot(2,2,2)
plt.boxplot(reliance['Close'])
plt.xlabel('Date')
plt.ylabel('Cloes Price')
plt.title('Close')
#Plot 3
plt.subplot(2,2,3)
plt.boxplot(reliance['High'])
plt.xlabel('Date')
plt.ylabel('High Price')
plt.title('High')
#Plot 4
plt.subplot(2,2,4)
plt.boxplot(reliance['Low'])
plt.xlabel('Date')
plt.ylabel('Low Price')
plt.title('Low')
# Out:
# Text(0.5, 1.0, 'Low')

# %% [markdown]
# From the box plot it is clear that there are no outliers inthe dataset

# %%
# Ploting Histogram
plt.figure(figsize=(20,18))
#Plot 1
plt.subplot(2,2,1)
plt.hist(reliance['Open'],bins=50, color='green')
plt.xlabel("Open Price")
plt.ylabel("Frequency")
plt.title('Open')
#Plot 2
plt.subplot(2,2,2)
plt.hist(reliance['Close'],bins=50, color='red')
plt.xlabel("Close Price")
plt.ylabel("Frequency")
plt.title('Close')
#Plot 3
plt.subplot(2,2,3)
plt.hist(reliance['High'],bins=50, color='green')
plt.xlabel("High Price")
plt.ylabel("Frequency")
plt.title('High')
#Plot 4
plt.subplot(2,2,4)
plt.hist(reliance['Low'],bins=50, color='red')
plt.xlabel("Low Price")
plt.ylabel("Frequency")
plt.title('Low')
# Out:
# Text(0.5, 1.0, 'Low')

# %%
# KDE-Plots
plt.figure(figsize=(20,10))
#Plot 1
plt.subplot(2,2,1)
sns.kdeplot(reliance['Open'], color='green')
plt.title('Open')
#Plot 2
plt.subplot(2,2,2)
sns.kdeplot(reliance['Close'], color='red')
plt.title('Close')
#Plot 3
plt.subplot(2,2,3)
sns.kdeplot(reliance['High'], color='green')
plt.title('High')
#Plot 4
plt.subplot(2,2,4)
sns.kdeplot(reliance['Low'], color='red')
plt.title('Low')
# Out:
# Text(0.5, 1.0, 'Low')

# %%
sns.heatmap(reliance.corr(),annot=True)
plt.show()

# %%
figure=plt.figure(figsize=(30,10))
plt.plot(reliance['Volume'])
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title('Date vs Volume')
plt.show()

# %% [markdown]
# ## Finding long-term and short-term trends

# %% [markdown]
# ### Moving Average

# %%
reliance_ma=reliance.copy()
reliance_ma['30-day MA']=reliance['Close'].rolling(window=30).mean()  #average closing price over the last 30 days
reliance_ma['200-day MA']=reliance['Close'].rolling(window=200).mean()  #average closing price over the last 200 days

# %%
# These moving averages are often used by traders and analysts to
#identify trends and make informed decisions about buying or selling the stock.
reliance_ma
# Out:
#                    Open         High          Low        Close   Volume  \
# Date
# 2015-01-01   438.988831   441.812073   437.676270   439.781311  1367720
# 2015-01-02   439.880371   443.818054   437.998199   438.617340  3383424
# 2015-01-05   438.344940   441.267212   432.946106   433.812897  4662967
# 2015-01-06   430.915344   432.401276   412.093750   414.124512  8596809
# 2015-01-07   414.619812   425.367950   414.570282   423.139069  9562421
# ...                 ...          ...          ...          ...      ...
# 2022-12-26  2514.750000  2542.000000  2492.399902  2524.050049  2764496
# 2022-12-27  2530.000000  2548.800049  2515.250000  2544.699951  2659749
# 2022-12-28  2538.000000  2549.800049  2521.500000  2544.449951  3442509
# 2022-12-29  2527.000000  2548.899902  2525.500000  2543.300049  3198493
# 2022-12-30  2545.100098  2577.000000  2541.100098  2547.199951  3364092
#
#               30-day MA   200-day MA
# Date
# 2015-01-01          NaN          NaN
# 2015-01-02          NaN          NaN
# 2015-01-05          NaN          NaN
# 2015-01-06          NaN          NaN
# 2015-01-07          NaN          NaN
# ...                 ...          ...
# 2022-12-26  2618.376693  2556.113508
# 2022-12-27  2616.290023  2557.659508
# 2022-12-28  2614.693351  2558.611257
# 2022-12-29  2612.835018  2559.366508
# 2022-12-30  2611.153353  2560.106758
#
# [1976 rows x 7 columns]

# %%
plt.figure(figsize=(20,10))
plt.plot(reliance_ma['Close'],label='Original data')
plt.plot(reliance_ma['30-day MA'],label='30-MA')
plt.legend()
plt.title('Stock Price vs 30-day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(reliance_ma['Close'],label='Original data')
plt.plot(reliance_ma['200-day MA'],label='200-MA')
plt.legend
plt.title('Stock Price vs 200-day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# Long term and short term trends can be identified using the Moving Average graphs
# - In long term, Stock price is in upward trend
# - Short term trends can be identified from MA-30 chart
# - Stock had a major short term downtrend during the year 2020
# - It may be due to the bearish market during the Covid-19 outbraek
